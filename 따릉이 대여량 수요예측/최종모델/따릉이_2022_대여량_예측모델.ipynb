# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

from scipy.stats import skew
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso, LogisticRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ## 전처리

# %%
test5 = pd.read_csv('2018_2021_전처리_최종.csv')
test5.round(2)
# Out:
#            총생활인구수    기온    기압    풍속    운량  일강수량  최대순간풍속풍향  최대풍속풍향  평균풍속  최다풍향  \
# 0     10534264.00  2.85 -1.16 -0.74 -1.88   0.0       320     290   1.4   290
# 1     12237724.00  2.94 -1.15  0.31 -1.74   0.0       270     290   1.8   290
# 2     12312633.00  3.38 -1.19 -1.03 -1.35   0.0       320     270   2.2   290
# 3     12368761.00  3.46 -1.19 -1.26 -1.19   0.0       320     320   1.4   290
# 4     12368042.00  3.00 -1.12 -0.57 -0.89   0.0       250     270   1.7   290
# ...           ...   ...   ...   ...   ...   ...       ...     ...   ...   ...
# 1456    475550.14  3.89 -1.15 -1.57 -0.06   0.0       340      20   1.7    50
# 1457    477997.80  3.13 -1.01 -1.74  1.34   0.0        50      50   2.2    50
# 1458    478029.06  2.20 -0.86  1.53  1.00   0.2       270     270   2.6    50
# 1459    476656.88  3.20 -1.15  2.36 -0.80   0.0       320     290   3.3   270
# 1460    463258.21  3.88 -1.26  1.57 -1.72   0.0       290     270   3.5   270
#
#       일최심적설  일최심신적설  강수여부  일 미세먼지 농도(㎍/㎥)  휴일여부  요일  계절  month  day    영등포구
# 0       0.0     0.0   0.0            38.0     1   0   4      1    1   421.0
# 1       0.0     0.0   0.0            32.0     0   1   4      1    2   820.0
# 2       0.0     0.0   0.0            32.0     0   2   4      1    3   839.0
# 3       0.0     0.0   0.0            40.0     0   3   4      1    4   749.0
# 4       0.0     0.0   0.0            46.0     0   4   4      1    5   878.0
# ...     ...     ...   ...             ...   ...  ..  ..    ...  ...     ...
# 1456    0.0     0.0   0.0            33.0     0   0   4     12   27  3517.0
# 1457    0.0     0.0   0.0            60.0     0   1   4     12   28  4214.0
# 1458    0.3     0.3   1.0            70.0     0   2   4     12   29  4126.0
# 1459    0.0     0.0   0.0            30.0     0   3   4     12   30  3883.0
# 1460    0.0     0.0   0.0            21.0     0   4   4     12   31  3294.0
#
# [1461 rows x 20 columns]

# %% [markdown]
# # LinearRegression, Ridge, Lasso

# %%
test5[[ '강수여부','휴일여부','요일', '계절', 'month','day',]]= test5[[ '강수여부','휴일여부','요일', '계절', 'month','day']].astype('str')

# %%
def get_rmse(model):
    import numpy as np
    from sklearn.metrics import mean_squared_error
    pred = model.predict(X_test)
    mse = mean_squared_error(y_test, pred)
    rmse = np.sqrt(mse)
    print(model.__class__.__name__, 'RMSE: ', np.round(rmse,3))
    return rmse
def get_rmses(models):
    rmses = []
    for model in models:
        rmse = get_rmse(model)
        rmses.append(rmse)
    return rmses

# %%
test5.shape
# Out:
# (1461, 20)

# %%
X = test5.drop(columns=['영등포구'])
y = test5['영등포구']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)

# %%
lr_reg = LinearRegression() #선형회귀
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models) # R2 점수 추가함
# Out:
# LinearRegression RMSE:  1772.777
# Ridge RMSE:  1773.044
# Lasso RMSE:  1772.809
# [1772.777210966064, 1773.0439393557238, 1772.809028944851]

# %%
# 왜곡도 확인
features_index = test5.dtypes[test5.dtypes != 'object'].index
skew_features= test5[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features>2]
skew_features_top.sort_values(ascending=False)

# 왜곡도 2 이상은 로그로 변환
# test5[skew_features_top.index]= np.log1p(test5[skew_features_top.index]+2)
np.log1p(test5[skew_features_top.index])
# Out:
#           일강수량     일최심적설    일최심신적설  일 미세먼지 농도(㎍/㎥)
# 0     0.000000  0.000000  0.000000        3.663562
# 1     0.000000  0.000000  0.000000        3.496508
# 2     0.000000  0.000000  0.000000        3.496508
# 3     0.000000  0.000000  0.000000        3.713572
# 4     0.000000  0.000000  0.000000        3.850148
# ...        ...       ...       ...             ...
# 1456  0.000000  0.000000  0.000000        3.526361
# 1457  0.000000  0.000000  0.000000        4.110874
# 1458  0.182322  0.262364  0.262364        4.262680
# 1459  0.000000  0.000000  0.000000        3.433987
# 1460  0.000000  0.000000  0.000000        3.091042
#
# [1461 rows x 4 columns]

# %%
test5.isna().sum()
# Out:
# 총생활인구수            0
# 기온                0
# 기압                0
# 풍속                0
# 운량                0
# 일강수량              0
# 최대순간풍속풍향          0
# 최대풍속풍향            0
# 평균풍속              0
# 최다풍향              0
# 일최심적설             0
# 일최심신적설            0
# 강수여부              0
# 일 미세먼지 농도(㎍/㎥)    0
# 휴일여부              0
# 요일                0
# 계절                0
# month             0
# day               0
# 영등포구              0
# dtype: int64

# %%
# y값 정규분포로 변환
log_test = np.log1p(test5['영등포구'])
sns.histplot(log_test, kde=True)
# Out:
# <AxesSubplot:xlabel='영등포구', ylabel='Count'>

# %%
# 문자열 치환 원앤핫인코딩
test5 = pd.get_dummies(test5)
X = test5.drop(columns=['영등포구'])
y = log_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)

# %%
# 모델 확인
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')
ridge_reg = Ridge()
ridge_reg.fit(X_train, y_train)
lasso_reg = Lasso()
lasso_reg.fit(X_train, y_train)
models = [lr_reg, ridge_reg, lasso_reg]
get_rmses(models)
# Out:
# MSE: 0.163803141315341, RMSE: 0.4047260077081049, R2: 0.7604133980740984
# LinearRegression RMSE:  0.405
# Ridge RMSE:  0.405
# Lasso RMSE:  0.703
# [0.4047260077081049, 0.40470106523696214, 0.7027315972280368]

# %%
# 루트치환값 다시 원래대로 돌려서 비교
y_t= np.expm1(y_test)
p_t = np.expm1(pred)
for solve, predd in zip(y_t, p_t):
    print(f'{solve}, {predd}')
# Out:
# 586.0000000000002, 572.1540297771314
# 6748.999999999997, 7926.735256791609
# 9834.000000000007, 8197.409350346943
# 3671.9999999999977, 2932.6120492299565
# 1302.0, 6003.736412693065
# 6253.999999999997, 6321.247778095493
# 5259.999999999995, 4512.265390842466
# 7453.999999999998, 7005.8862486678945
# 3324.999999999998, 3596.6214344584228
# 2134.000000000001, 1913.4210735224685
# 5773.000000000005, 3960.1151926594566
# 2916.999999999999, 3472.959070756839
# 7352.0, 7270.519054275036
# 3341.999999999998, 3614.1305774080174
# 7408.999999999999, 5886.39675269123
# 219.00000000000009, 1332.9822798987952
# 8484.000000000004, 8250.753790072395
# 12169.00000000001, 8524.84363720512
# 1603.0000000000005, 1734.0804483647917
# 8444.999999999995, 7560.96374417899
# 8398.000000000005, 8751.610075982471
# 1100.9999999999995, 847.2260632888048
# 2863.000000000001, 2645.3875433915528
# 8422.999999999995, 6997.608343405342
# 5702.0, 4899.528588424882
# 3802.9999999999973, 3396.8772178321715
# 6427.0, 6196.4567148713695
# 2913.0, 3211.9089341453705
# 1793.9999999999998, 931.0449121131519
# 390.9999999999999, 524.1111969545561
# 4540.000000000001, 4286.073936589724
# 1503.0000000000005, 1997.0730768767382
# 7821.9999999999945, 7216.809114516573
# 1800.9999999999998, 3570.0150314215134
# 698.9999999999998, 644.8599892527618
# 8736.0, 7511.455519889202
# 5554.000000000003, 4281.489873088256
# 1325.9999999999995, 1340.2815744863233
# 8055.0000000000055, 7318.930158573511
# 8861.999999999996, 7483.433417687504
# 10543.999999999996, 8264.50874098168
# 569.0000000000002, 665.3305509500827
# 869.0000000000002, 692.7751188301605
# 4004.999999999997, 3634.5656810800087
# 5179.999999999995, 3444.2727463998026
# 1407.9999999999995, 1302.7690636356715
# 2180.9999999999995, 1836.7123000449503
# 5994.999999999995, 5886.39675269123
# 3477.999999999998, 3142.1465273116314
# 3417.0000000000027, 3933.6408987219324
# 6914.999999999998, 7857.3724887639055
# 8031.999999999997, 8221.430759538254
# 7789.000000000001, 6399.615669432345
# 2588.0000000000005, 2008.9954715634801
# 6471.999999999999, 7671.065902395863
# 1593.0000000000005, 2903.3909505711463
# 3778.9999999999986, 2531.9304047645046

# %% [markdown]
# ## cross_val_score
# -  LinearRegression, Ridge, Lasso 교차검증

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
X_data = test5.drop(columns=['영등포구'])
y_target = test5['영등포구']


ridge = Ridge(alpha=5)
neg_mse_scores = cross_val_score(ridge, X_data, y_target, scoring="neg_mean_squared_error",cv=5)
rmse_scores = np.sqrt(-1*neg_mse_scores)
avg_rmse = np.mean(rmse_scores)

# %%
def get_avg_rmse_cv(models):
    for model in models:
        rmse_list = np.sqrt(-cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=5)) #rmse = 5개가 나올 것
        rmse_avg = np.mean(rmse_list)
        print(f'{model.__class__.__name__} cv rmse 값 리스트 : {np.round(rmse_list,3)}')
        print(f'{model.__class__.__name__} cv 평균 rmse 값 : {np.round(rmse_avg,3)}')

get_avg_rmse_cv(models)
# Out:
# LinearRegression cv rmse 값 리스트 : [0.417 0.506 0.454 0.457 0.479]
# LinearRegression cv 평균 rmse 값 : 0.462
# Ridge cv rmse 값 리스트 : [0.418 0.505 0.453 0.455 0.479]
# Ridge cv 평균 rmse 값 : 0.462
# Lasso cv rmse 값 리스트 : [0.848 0.782 0.694 0.635 0.808]
# Lasso cv 평균 rmse 값 : 0.753

# %% [markdown]
# ## GridSearchCV
# LinearRegression, Ridge, Lasso 하이퍼파라미터 조정

# %%
from sklearn.model_selection import GridSearchCV

# %%
def print_best_params(model,params):
    grid_model = GridSearchCV(model,params,scoring='neg_mean_squared_error', cv=10) #GridSearchCV라서 scoring='neg' #scoring='neg_mean_squared_error' 예측값과 차이의 제곱?
    grid_model.fit(X,y)
    rmse = np.sqrt(-1*grid_model.best_score_)
    print(f'{model.__class__.__name__} 5 cv시 최적 평균 rmse 값:{np.round(rmse, 4)}, 최적 alpha값:{grid_model.best_params_}')

# %%
ridge_param = {
    'alpha':[0.0001,0.01,0.05, 0.1, 1, 5, 8, 10, 12, 15, 20, 30, 40, 50, 100]
} #ridge더 크게 rasso 더 작게
print_best_params(ridge_reg, ridge_param)
# Out:
# Ridge 5 cv시 최적 평균 rmse 값:0.4501, 최적 alpha값:{'alpha': 20}

# %%
lasso_param = {'alpha':[0.0001,0.001, 0.005, 0.008, 0.05, 0.05, 0.1, 0.5, 1, 5, 10, 15, 30]} 
print_best_params(lasso_reg, lasso_param)
# Out:
# Lasso 5 cv시 최적 평균 rmse 값:0.4498, 최적 alpha값:{'alpha': 0.001}

# %%
lr_reg = LinearRegression()
lr_reg.fit(X_train,y_train)

ridge_reg = Ridge(alpha=20)
ridge_reg.fit(X_train,y_train)

lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(X_train,y_train)

models=[lr_reg, ridge_reg,lasso_reg] 
get_rmses(models)

#visualize_coefficient(models)
# Out:
# LinearRegression RMSE:  0.405
# Ridge RMSE:  0.406
# Lasso RMSE:  0.403
# [0.4047260077081049, 0.40641955953603925, 0.4031954508258862]

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=32)

log_test = np.log1p(test5['영등포구'])
test5 = pd.get_dummies(test5)
X = test5.drop(columns=['영등포구'])
y = log_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)

rf_clf = RandomForestRegressor(random_state=32, max_depth=8)
rf_clf.fit(X_train,y_train)

pred = rf_clf.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')
# Out:
# MSE: 0.12283794091253145, RMSE: 0.35048244023421693, R2: 0.8203311327580028

# %%
## GridSearchCV 
# RandomForestRegressor - 하이퍼 파라미터 수정

from sklearn.model_selection import GridSearchCV

params = {
    'max_depth': [6, 12, 18, 26],
    'min_samples_leaf': [6, 12, 18, 24],
    'min_samples_split':[6, 12, 18, 24]
}

rf_clf_gs = RandomForestRegressor(n_estimators=100, random_state=32, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf_gs, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_train, y_train)

print('최적 하이퍼 파라미너:\n', grid_cv.best_params_)
# Out:
# 최적 하이퍼 파라미너:
#  {'max_depth': 12, 'min_samples_leaf': 6, 'min_samples_split': 6}

# %%
rf_clf1    = RandomForestRegressor(n_estimators=100, max_depth=12, min_samples_leaf=1, min_samples_split=6, random_state=32)
rf_clf1.fit(X_train,y_train)

pred = rf_clf1.predict(X_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')
# Out:
# MSE: 0.11591028078606788, RMSE: 0.34045598949947686, R2: 0.8304638721894262

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from xgboost import XGBRegressor

# %%
import xgboost

print(xgboost.__version__)
# Out:
# 1.5.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#학습용(80%), 데이터용(20%)
log_test = np.log1p(test5['영등포구'])
#test = test5['영등포구']
test5 = pd.get_dummies(test5)
X = test5.drop(columns=['영등포구'])
y = log_test
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)

# %%
#최종 학습용(90%), 검즘용(10%)
X_tr, X_val, y_tr, y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=32)

# %%
#학습, 검증, 테스트용 DMatrix 생성
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %%
params = {
    'max_depth':3,
    'eta':0.05,
    #'objective':'binary:logistic',
    # 'eval_metric':'logloss'
}
num_rounds = 400

# %%
eval_list = [(dtr,'train'),(dval,'eval')]
xgb_model = xgb.train(params = params, dtrain=dtr, num_boost_round=num_rounds,
                      early_stopping_rounds=500, evals=eval_list)

# pred = xgb_model.predict(dtest)
# print(pred)

pred = xgb_model.predict(dtest)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')
# Out:
# [0]	train-rmse:7.37034	eval-rmse:7.36276
# [1]	train-rmse:7.00529	eval-rmse:7.00104
# [2]	train-rmse:6.65851	eval-rmse:6.65743
# [3]	train-rmse:6.32910	eval-rmse:6.33105
# [4]	train-rmse:6.01596	eval-rmse:6.02216
# [5]	train-rmse:5.71868	eval-rmse:5.72708
# [6]	train-rmse:5.43613	eval-rmse:5.44651
# [7]	train-rmse:5.16784	eval-rmse:5.17877
# [8]	train-rmse:4.91275	eval-rmse:4.92722
# [9]	train-rmse:4.67057	eval-rmse:4.68624
# [10]	train-rmse:4.44061	eval-rmse:4.45670
# [11]	train-rmse:4.22192	eval-rmse:4.24123
# [12]	train-rmse:4.01426	eval-rmse:4.03686
# [13]	train-rmse:3.81702	eval-rmse:3.84136
# [14]	train-rmse:3.62969	eval-rmse:3.65690
# [15]	train-rmse:3.45176	eval-rmse:3.47844
# [16]	train-rmse:3.28270	eval-rmse:3.31142
# [17]	train-rmse:3.12216	eval-rmse:3.15321
# [18]	train-rmse:2.96971	eval-rmse:3.00060
# [19]	train-rmse:2.82484	eval-rmse:2.85743
# [20]	train-rmse:2.68718	eval-rmse:2.72049
# [21]	train-rmse:2.55658	eval-rmse:2.59160
# [22]	train-rmse:2.43258	eval-rmse:2.46757
# [23]	train-rmse:2.31476	eval-rmse:2.35048
# [24]	train-rmse:2.20283	eval-rmse:2.23855
# [25]	train-rmse:2.09667	eval-rmse:2.13334
# [26]	train-rmse:1.99595	eval-rmse:2.03280
# [27]	train-rmse:1.90018	eval-rmse:1.93886
# [28]	train-rmse:1.80947	eval-rmse:1.84862
# [29]	train-rmse:1.72337	eval-rmse:1.76306
# [30]	train-rmse:1.64159	eval-rmse:1.68373
# [31]	train-rmse:1.56400	eval-rmse:1.60544
# 219.00000000000009, 1083.734375
# 8484.000000000004, 8761.5
# 12169.00000000001, 8730.7275390625
# 1603.0000000000005, 1780.6153564453125
# 8444.999999999995, 7701.2177734375
# 8398.000000000005, 9543.92578125
# 1100.9999999999995, 1032.3348388671875
# 2863.000000000001, 2546.89013671875
# 8422.999999999995, 7897.43994140625
# 5702.0, 5198.42333984375
# 3802.9999999999973, 3692.408203125
# 6427.0, 6705.0302734375
# 2913.0, 3243.111083984375
# 1793.9999999999998, 1221.8099365234375
# 390.9999999999999, 809.7323608398438
# 4540.000000000001, 4837.4111328125
# 1503.0000000000005, 1589.9066162109375
# 7821.9999999999945, 8506.8388671875
# 1800.9999999999998, 3571.01220703125
# 698.9999999999998, 602.0197143554688
# 8736.0, 8607.126953125
# 5554.000000000003, 4386.56201171875
# 1325.9999999999995, 1478.5169677734375
# 8055.0000000000055, 7199.51220703125
# 8861.999999999996, 8308.3125
# 10543.999999999996, 9111.8447265625
# 569.0000000000002, 898.1336059570312
# 869.0000000000002, 793.2609252929688
# 4004.999999999997, 3310.078125
# 5179.999999999995, 3788.30810546875
# 1407.9999999999995, 1395.016845703125
# 2180.9999999999995, 1836.9595947265625
# 5994.999999999995, 6165.994140625
# 3477.999999999998, 3337.622802734375
# 3417.0000000000027, 3286.97216796875
# 6914.999999999998, 8435.4638671875
# 8031.999999999997, 8280.8212890625
# 7789.000000000001, 7281.77783203125
# 2588.0000000000005, 2127.46240234375
# 6471.999999999999, 7302.09375
# 1593.0000000000005, 2540.575439453125
# 3778.9999999999986, 2527.9267578125

# %% [markdown]
# # GBM

# %%
from sklearn.ensemble import GradientBoostingRegressor
import time

# %%
gb_ref = GradientBoostingRegressor(random_state=32)
gb_ref.fit(X_train, y_train)
gb_pred = gb_ref.predict(X_test)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')
# Out:
# RMSE:  0.35
# R2: 0.8206695227981383

# %%
params = {
    'max_depth':[3],
    'learning_rate':[0.05],
    #'objective':'binary:logistic',
    # 'eval_metric':'logloss'
}
num_rounds = 400

# %%
grid_cv = GridSearchCV(gb_ref, param_grid=params , cv = 2, n_jobs=-1)
grid_cv.fit(X_train, y_train)
pred = grid_cv.predict(X_test)

print(grid_cv.best_params_)
print(grid_cv.best_score_)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
print('MSE: ', np.round(mse,3))
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, pred)}')
# Out:
# {'learning_rate': 0.05, 'max_depth': 3}
# 0.8143609497947379
# MSE:  0.131
# RMSE:  0.361
# R2: 0.8090403174312449

# %% [markdown]
# # LightGBM

# %%
from lightgbm import LGBMRegressor

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=32)
lgbm = LGBMRegressor(n_estimators=100, learning_rate=0.05)

evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
preds = lgbm.predict(X_test)

mse = mean_squared_error(y_test, preds)
rmse = np.sqrt(mse)

print('MSE: ', np.round(mse,3))
print('RMSE: ', np.round(rmse,3))
print(f'R2: {r2_score(y_test, preds)}')
# Out:
# [1]	training's l2: 0.666447	valid_1's l2: 0.696316
# Training until validation scores don't improve for 100 rounds
# [2]	training's l2: 0.61707	valid_1's l2: 0.650066
# [3]	training's l2: 0.572415	valid_1's l2: 0.607367
# [4]	training's l2: 0.531833	valid_1's l2: 0.571331
# [5]	training's l2: 0.494959	valid_1's l2: 0.534772
# [6]	training's l2: 0.461334	valid_1's l2: 0.504657
# [7]	training's l2: 0.430049	valid_1's l2: 0.475325
# [8]	training's l2: 0.402175	valid_1's l2: 0.448074
# [9]	training's l2: 0.377113	valid_1's l2: 0.423734
# [10]	training's l2: 0.353461	valid_1's l2: 0.402901
# [11]	training's l2: 0.331773	valid_1's l2: 0.38118
# [12]	training's l2: 0.312232	valid_1's l2: 0.363782
# [13]	training's l2: 0.293738	valid_1's l2: 0.34657
# [14]	training's l2: 0.277174	valid_1's l2: 0.332685
# [15]	training's l2: 0.261436	valid_1's l2: 0.316519
# [16]	training's l2: 0.247291	valid_1's l2: 0.302729
# [17]	training's l2: 0.234549	valid_1's l2: 0.290169
# [18]	training's l2: 0.222556	valid_1's l2: 0.278059
# [19]	training's l2: 0.210582	valid_1's l2: 0.268139
# [20]	training's l2: 0.200797	valid_1's l2: 0.259112
# [21]	training's l2: 0.190411	valid_1's l2: 0.250222
# [22]	training's l2: 0.181122	valid_1's l2: 0.242144
# [23]	training's l2: 0.17265	valid_1's l2: 0.235102
# [24]	training's l2: 0.165001	valid_1's l2: 0.228788
# [25]	training's l2: 0.157892	valid_1's l2: 0.222717
# [26]	training's l2: 0.151333	valid_1's l2: 0.217739
# [27]	training's l2: 0.145045	valid_1's l2: 0.213009
# [28]	training's l2: 0.13944	valid_1's l2: 0.208565
# [29]	training's l2: 0.134076	valid_1's l2: 0.204481
# [30]	training's l2: 0.128871	valid_1's l2: 0.199787
# [31]	training's l2: 0.124227	valid_1's l2: 0.195134
# [32]	training's l2: 0.120137	valid_1's l2: 0.192281
# [33]	training's l2: 0.11611	valid_1's l2: 0.188834
# [34]	training's l2: 0.112289	valid_1's l2: 0.184149
# [35]	training's l2: 0.109	valid_1's l2: 0.181737
# [36]	training's l2: 0.105722	valid_1's l2: 0.177325
# [37]	training's l2: 0.102616	valid_1's l2: 0.173642
# [38]	training's l2: 0.0997524	valid_1's l2: 0.170062
# [39]	training's l2: 0.0972821	valid_1's l2: 0.168857
# [40]	training's l2: 0.0948506	valid_1's l2: 0.166204
# [41]	training's l2: 0.0926139	valid_1's l2: 0.163111
# [42]	training's l2: 0.0905246	valid_1's l2: 0.160102
# [43]	training's l2: 0.0885127	valid_1's l2: 0.159499
# [44]	training's l2: 0.0866739	valid_1's l2: 0.157538
# [45]	training's l2: 0.0848729	valid_1's l2: 0.156419
# [46]	training's l2: 0.0832092	valid_1's l2: 0.154398
# [47]	training's l2: 0.0816227	valid_1's l2: 0.153246
# [48]	training's l2: 0.0801227	valid_1's l2: 0.152433
# - LinearRegression, Ridge, Lasso(GridSearchCV)
# MSE: 0.14289231981722259, RMSE: 0.378011004889041, R2: 0.7909986031317261
# LinearRegression RMSE:  0.378
# Ridge RMSE:  0.435
# Lasso RMSE:  0.421
#
#
# - RandomForestRegressor(log1p적용)
# MSE: 0.1230143675763507, RMSE: 0.35073404108576445, R2: 0.82007308236572
#
# - RandomForestRegressor(GridSearchCV)
# MSE: 0.11591986683961727, RMSE: 0.3404700674649936, R2: 0.830449851151872583
#
#
# - XGBoost
# MSE: 0.12232982213943464, RMSE: 0.3497568042789656, R2: 0.8210743324869181
#
# - GBM
# MSE: 0.118, RMSE:  0.361, R2: 0.8089568079535943
#
# - LightGBM
# MSE: 0.123, RMSE:  0.351, R2: 0.8193671430432468

# %% [markdown]
# # 최종 결과
# MSE: RandomForestRegressor(GridSearchCV), MSE: 0.11
# RMSE: RandomForestRegressor(GridSearchCV), RMSE: 0.34
# R2: RandomForestRegressor(GridSearchCV), R2: 0.83

# %% [markdown]
# # 22년 1월 ~ 6월 데이터 입력하여 대여량 예측하기

# %% [markdown]
# * RandomForestRegressor(GridSearchCV) 를 통해 학습한 모델이 가장 높은 성과를 내보임
# * 22년 1월 ~ 6월 자료를 가지고 모델 예측성과 확인하기

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# * 모델로 예측하기
# * 랜덤포레스트 회귀 - gridsearchCV를 통해 찾아낸 파라미터 적용한 모델에 22년 데이터 입력하여 확인하기

#### 예측 준비

df = pd.read_csv('2022_전처리_최종.csv')
sample = df

# 왜곡도 확인
features_index = sample.dtypes[sample.dtypes != 'object'].index
skew_features= sample[features_index].apply(lambda x : skew(x))
skew_features_top = skew_features[skew_features>2]
skew_features_top.sort_values(ascending=False)

# 왜곡도 2 이상은 로그로 변환
# test5[skew_features_top.index]= np.log1p(test5[skew_features_top.index]+2)
np.log1p(sample[skew_features_top.index])


# 원핫인코딩 실시
sample[[ '강수여부','휴일여부','요일', '계절', 'month','day',]]= sample[[ '강수여부','휴일여부','요일', '계절', 'month','day']].astype('str')
sample = pd.get_dummies(sample)

sample['month_7'] = 0
sample['month_8'] = 0
sample['month_9'] = 0
sample['month_10'] = 0
sample['month_11'] = 0
sample['month_12'] = 0
sample['계절_3'] = 0

## 예측모델 결과

X_22 = sample.drop(columns = '영등포구')
y_22 = sample['영등포구'] # 실제 22년 1월 ~ 6월 대여량

y_ans = np.log1p(y_22)

# %%
lr_reg_pred_22 = lr_reg.predict(X_22)
mse = mean_squared_error(y_ans, lr_reg_pred_22)
rmse = np.sqrt(mse)
print('### 선형회귀 예측모델 결과 ###')
print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_ans, lr_reg_pred_22)}')
# Out:
# ### 선형회귀 예측모델 결과 ###
# MSE: 0.3551661653130587, RMSE: 0.5959581909102841, R2: 0.1043291826113597

# %%
ridge_reg_pred_22 = ridge_reg.predict(X_22)
mse = mean_squared_error(y_ans, ridge_reg_pred_22)
rmse = np.sqrt(mse)
print()
print('### 릿지 예측모델 결과 ###')
print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_ans, ridge_reg_pred_22)}')
# Out:
# ### 릿지 예측모델 결과 ###
# MSE: 0.35526409216953236, RMSE: 0.5960403444143125, R2: 0.10408222714051774

# %% [markdown]
# # 그래프

# %%
lasso_reg_pred_22 = lasso_reg.predict(X_22)
mse = mean_squared_error(y_ans, lasso_reg_pred_22)
rmse = np.sqrt(mse)
print()
print('###라쏘 예측모델 결과 ###')
print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_ans, lasso_reg_pred_22)}')
# Out:
# ###라쏘 예측모델 결과 ###
# MSE: 0.3204748439431654, RMSE: 0.5661049760805547, R2: 0.19181500531149276

# %%
x_li = []
y_li = []
for solve, predd in zip(np.expm1(y_ans), np.expm1(lasso_reg_pred_22)):
    # print(f'{solve}, {predd}')
    x_li.append(solve)
    y_li.append(predd)
num_li = np.arange(len(x_li))
x = num_li[:30]
y = x_li[:30]
z = y_li[:30]
plt.figure(figsize=(25,15))
plt.plot(x, y,  'rx:', label = 'pred') # cyan 색, square 마커
plt.plot(x, z,  label = 'y_test', color='mediumseagreen')
plt.title(" Lasso 결과 (정답-예측값) ")
plt.legend() # 범례 표시
plt.savefig('myfigure.png', transparent = True)
# sns.histplot(df['영등포구'], kde=True, color='mediumseagreen') # 정규분포 확인

# %%
rf_clf_pred_22 = rf_clf.predict(X_22)
mse = mean_squared_error(y_ans, rf_clf_pred_22)
rmse = np.sqrt(mse)
print()
print('### 랜덤포레스트 예측모델 결과 ###')
print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_ans, rf_clf_pred_22)}')
# Out:
# ### 랜덤포레스트 예측모델 결과 ###
# MSE: 0.4679549961908833, RMSE: 0.684072361808956, R2: -0.18010575013513486

# %%
x_li = []
y_li = []
for solve, predd in zip(np.expm1(y_ans), np.expm1(rf_clf_pred_22)):
    # print(f'{solve}, {predd}')
    x_li.append(solve)
    y_li.append(predd)
num_li = np.arange(len(x_li))
x = num_li[:30]
y = x_li[:30]
z = y_li[:30]
plt.figure(figsize=(25,15))
plt.plot(x, y,  'rx:', label = 'pred') # cyan 색, square 마커
plt.plot(x, z,  label = 'y_test', color='mediumseagreen')
plt.title(" RandomForestRegressor 결과 (정답-예측값) ")
plt.legend() # 범례 표시
plt.savefig('myfigure.png', transparent = True)
# sns.histplot(df['영등포구'], kde=True, color='mediumseagreen') # 정규분포 확인

# %%
x_li = []
y_li = []
for solve, predd in zip(np.expm1(y_ans), np.expm1(lasso_reg_pred_22)):
    # print(f'{solve}, {predd}')
    x_li.append(solve)
    y_li.append(predd)
num_li = np.arange(len(x_li))
x = num_li[:30]
y = x_li[:30]
z = y_li[:30]
plt.figure(figsize=(25,15))
plt.plot(x, y,  'rx:', label = 'pred') # cyan 색, square 마커
plt.plot(x, z,  label = 'y_test', color='mediumseagreen')
plt.legend() # 범례 표시
plt.savefig('myfigure.png', transparent = True)
# sns.histplot(df['영등포구'], kde=True, color='mediumseagreen') # 정규분포 확인

# %%
x_li = []
y_li = []
y_t= np.expm1(y_ans)
p_t = np.expm1(lasso_reg_pred_22)
print('### 라쏘 예측모델 결과 ###')
for solve, predd in zip(y_t, p_t):
    # print(f'{solve}, {predd}') 
    x_li.append(solve)
    y_li.append(predd)    

num_li = np.arange(len(x_li))
x = 
y = x_li
z = y_li


plt.figure(figsize=(25,15))
plt.plot(x, y, 'cs--', label = 'graph1') # cyan 색, square 마커
plt.plot(x, z, 'rx:', label = 'graph2')
plt.legend() # 범례 표시
plt.show()
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_15800\3294942805.py", line 12
#     x =
#         ^
# SyntaxError: invalid syntax

# %%
y_t= np.expm1(y_ans)
p_t = np.expm1(ridge_reg_pred_22)
print('### 릿지 예측모델 결과 ###')
for solve, predd in zip(y_t, p_t):
    print(f'{solve}, {predd}')

# %%
y_t= np.expm1(y_ans)
p_t = np.expm1(lr_reg_pred_22)
print('### 선형회귀 예측모델 결과 ###')
for solve, predd in zip(y_t, p_t):
    print(f'{solve}, {predd}')

# %%
# test5 = pd.read_csv('2018_2021_전처리_최종.csv')

# %%
# idx = test5[test5['month'] > 6].index

# test6 =test5.drop(idx)
# test6[[ '강수여부','휴일여부','요일', '계절', 'month','day',]]= test6[[ '강수여부','휴일여부','요일', '계절', 'month','day']].astype('str')

# %%
# test6 = pd.get_dummies(test6)

# %%
# test6.columns

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import accuracy_score
# import pandas as pd
# import warnings
# warnings.filterwarnings('ignore')


# log_test = np.log1p(test5['영등포구'])
# test5 = pd.get_dummies(test5)
# X = test5.drop(columns=['영등포구'])
# y = log_test
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=32)


# rf_clf = RandomForestRegressor(random_state=32, max_depth=8)
# rf_clf.fit(X_train,y_train)


# pred = rf_clf.predict(X_test)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)

# print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

# %%
# ## GridSearchCV 
# # RandomForestRegressor - 하이퍼 파라미터 수정

# from sklearn.model_selection import GridSearchCV

# params = {
#     'max_depth': [6, 12, 18, 26, 30],
#     'min_samples_leaf': [1, 6, 12, 18, 24],
#     'min_samples_split':[2, 6, 12, 18, 24]
# }

# rf_clf = RandomForestRegressor(n_estimators=100, random_state=32, n_jobs=-1)
# grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1)
# grid_cv.fit(X_train, y_train)

# print('최적 하이퍼 파라미너:\n', grid_cv.best_params_)

# %%
# rf_clf1    = RandomForestRegressor(n_estimators=100, max_depth=12, min_samples_leaf=1, min_samples_split=2, random_state=32)
# rf_clf1.fit(X_train,y_train)

# pred = rf_clf1.predict(X_test)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)

# print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')

# %%
# pred = xgb_model.predict(X_22)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)
# print()
# print('### XGBoost 예측모델 결과 ###')
# print(f'MSE: {mse}, RMSE: {rmse}, R2: {r2_score(y_test, pred)}')


# pred = grid_cv.predict(X_22)
# mse = mean_squared_error(y_test, pred)
# rmse = np.sqrt(mse)
# print()
# print('### GBM 예측모델 결과 ###')
# print('MSE: ', np.round(mse,3))
# print('RMSE: ', np.round(rmse,3))
# print(f'R2: {r2_score(y_test, pred)}')
